# %%
# %run BoInLab.py

# %%
#data prep
data_file = "bo_test_exp_data_with_full_params.csv"

# %%
#by default, full descriptor will be selected and 0 in the observable column will be removed as invalid data
#the boundary will be set as 10% larger than current data spread region.
bil = BoInLab(data_file, set_pbound_mode = "smooth", buffer_percent = 0.1)

#example of selected descriptor:
# bil = BoInLab(data_file, sel_descriptor=["D", "H"])

#example of changing invalid data value
# bil = BoInLab(data_file, rm_zero_by = -1)

#example of fix pbound for some descriptors:
# bil = BoInLab(data_file, set_pbound_mode = "fix_for_selected", pbound_for = {'D':(10,16), "HBD": (1, 20)}, buffer_percent = 0.1)
# Out:
# pbound for all descriptors:
#
# {'D': (14.85, 19.05), 'P': (3.8099999999999996, 19.29), 'H': (2.66, 18.74), 'epsilon': (1.9769999999999985, 50.493), 'pi_star': (0.351, 1.059), 'HBD': (-0.084, 0.9239999999999999), 'HBA': (0.34700000000000003, 0.9830000000000001), 'logP_solv': (-1.5899999999999999, 0.9299999999999999), 'r_sm': (2.0411974332640384, 13.815624740183257), 'r_prod': (1.3333658081323423, 17.03660366323923)}

# %%
bil.init_bayesian(acq_func = "ucb", ucb_kappa = 0)
# Out:
# Register Xf2346...
# Done.
# Register Xf2353...
# Done.
# Register Xf2345...
# Done.
# Register Xf2344...
# Done.
# Register Xf2352...
# Done.
# Register Xf2350...
# Done.
# Register Xf2351...
# Done.
# Register Xf2356...
# Done.
# Register xf2379...
# Done.
# Register xf2380...
# Done.
# Register xf2381...
# Done.
# Register xf2382...
# Done.
# Register xf2383...
# Done.
# Register xf2384...
# Done.
# Register xf2385...
# Done.
# Register xf2386...
# Done.
# Register xf2387...
# Done.
# Register xf2388...
# Done.
# Register xf2389...
# Done.
# Register xf2391...
# Done.
# Register xf2392...
# Done.
# Register xf2393...
# Done.
# Register xf2394...
# Done.
# Register xf2396...
# Done.
# ucb
# ucb_kappa=0
# Suggested next point to go:
# {'D': 18.300551898932707, 'H': 3.9565385783015365, 'HBA': 0.7909939392070712, 'HBD': -0.084, 'P': 8.837041024765533, 'epsilon': 31.943409006468183, 'logP_solv': -0.5413567693200543, 'pi_star': 0.9261627690994135, 'r_prod': 1.7476891141715367, 'r_sm': 6.4634086519051435}

# %%
bil.plot_res()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[457], line 1
# ----> 1 bil.plot_res()
#
# File ~\OneDrive - University of Bristol\Documents\MyCode\learn_opt\BoInLab.py:343, in BoInLab.plot_res(self, plot_mode, two_to_plot)
#     341 X_descpt_0, X_descpt_1 = np.mgrid[descpt_0_pbound_min:descpt_0_pbound_max:101j, descpt_1_pbound_min:descpt_1_pbound_max:101j]
#     342 xdescpt = [[x_descpt_0, x_descpt_1] for x_descpt_0, x_descpt_1 in zip(X_descpt_0.flatten(), X_descpt_1.flatten())]
# --> 343 util_flat = self.utility.utility(xdescpt, self.optimizer._gp, self.optimizer.max['target'])
#     344 util = util_flat.reshape(101, 101)
#     347 # print(res_coord)
#
# File ~\anaconda3\envs\chem-rdkit\lib\site-packages\bayes_opt\util.py:148, in UtilityFunction.utility(self, x, gp, y_max)
#     146 def utility(self, x, gp, y_max):
#     147     if self.kind == 'ucb':
# --> 148         return self._ucb(x, gp, self.kappa)
#     149     if self.kind == 'ei':
#     150         return self._ei(x, gp, y_max, self.xi)
#
# File ~\anaconda3\envs\chem-rdkit\lib\site-packages\bayes_opt\util.py:158, in UtilityFunction._ucb(x, gp, kappa)
#     156 with warnings.catch_warnings():
#     157     warnings.simplefilter("ignore")
# --> 158     mean, std = gp.predict(x, return_std=True)
#     160 return mean + kappa * std
#
# File ~\anaconda3\envs\chem-rdkit\lib\site-packages\sklearn\gaussian_process\_gpr.py:408, in GaussianProcessRegressor.predict(self, X, return_std, return_cov)
#     405 else:
#     406     dtype, ensure_2d = None, False
# --> 408 X = self._validate_data(X, ensure_2d=ensure_2d, dtype=dtype, reset=False)
#     410 if not hasattr(self, "X_train_"):  # Unfitted;predict based on GP prior
#     411     if self.kernel is None:
#
# File ~\anaconda3\envs\chem-rdkit\lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File ~\anaconda3\envs\chem-rdkit\lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 2 features, but GaussianProcessRegressor is expecting 10 features as input.

# %%
bil.res
# Out:
# {'D': 18.300551898932707,
#  'H': 3.9565385783015365,
#  'HBA': 0.7909939392070712,
#  'HBD': -0.084,
#  'P': 8.837041024765533,
#  'epsilon': 31.943409006468183,
#  'logP_solv': -0.5413567693200543,
#  'pi_star': 0.9261627690994135,
#  'r_prod': 1.7476891141715367,
#  'r_sm': 6.4634086519051435}

# %%
#bil.register_data()
# Out:
# Register Xf2346...
# Done.
# Register Xf2353...
# Done.
# Register Xf2345...
# Done.
# Register Xf2344...
# Done.
# Register Xf2352...
# Done.
# Register Xf2350...
# Done.
# Register Xf2351...
# Done.
# Register Xf2356...
# Done.
# Register xf2379...
# Done.
# Register xf2380...
# Done.
# Register xf2381...
# Done.
# Register xf2382...
# Done.
# Register xf2383...
# Done.
# Register xf2384...
# Done.
# Register xf2385...
# Done.
# Register xf2386...
# Done.
# Register xf2387...
# Done.
# Register xf2388...
# Done.
# Register xf2389...
# Done.
# Register xf2391...
# Done.
# Register xf2392...
# Done.
# Register xf2393...
# Done.
# Register xf2394...
# Done.
# Register xf2396...
# Done.

# %%
bil.all_descpt_col_name
# Out:
# ['D',
#  'P',
#  'H',
#  'epsilon',
#  'pi_star',
#  'HBD',
#  'HBA',
#  'logP_solv',
#  'r_sm',
#  'r_prod']

# %%
#check data_file by calling self.origin_data
bil.origin_data.head()
# Out:
#          solv_1  percent_1 solv_2  percent_2     Y     D     P     H  epsilon  \
# rxn_id
# Xf2346     DMAC        1.0    NaN        NaN  0.82  16.8  11.5  10.2    37.78
# Xf2353  Acetone        1.0    NaN        NaN  0.72  15.5  10.4   7.0    20.70
# Xf2345     DMSO        1.0    NaN        NaN  0.70  18.4  16.4  10.2    46.45
# Xf2344      DMF        1.0    NaN        NaN  0.62  17.4  13.7  11.3    36.70
# Xf2352      ACN        1.0    NaN        NaN  0.52  15.3  18.0   6.1    37.50
#
#         pi_star   HBD   HBA  logP_solv       r_sm     r_prod
# rxn_id
# Xf2346     0.88  0.00  0.76      -0.77   4.843800  10.141006
# Xf2353     0.60  0.10  0.50      -0.21   8.462175   7.942921
# Xf2345     1.00  0.00  0.76      -1.38   7.907490  13.600368
# Xf2344     0.88  0.00  0.69      -1.31   5.234539  12.269067
# Xf2352     0.75  0.19  0.40      -0.39  12.834422  13.691603

# %%
# get observable series: bil.obs_series
bil.obs_series
# Out:
# rxn_id
# Xf2346    0.82
# Xf2353    0.72
# Xf2345    0.70
# Xf2344    0.62
# Xf2352    0.52
# Xf2350    0.26
# Xf2351    0.14
# Xf2356    0.01
# xf2379    0.35
# xf2380    0.59
# xf2381    0.04
# xf2382    0.20
# xf2383    0.25
# xf2384    0.23
# xf2385    0.29
# xf2386    0.25
# xf2387    0.64
# xf2388    0.50
# xf2389    0.82
# xf2391    0.53
# xf2392    0.63
# xf2393    0.60
# xf2394    0.72
# xf2396    0.62
# Name: Y, dtype: float64

# %%
print(bil.descriptor_df.iloc[0].name)
# Out:
# Xf2346

# %%
#we can check statistical details for both obs and descriptors using
bil.obs_stats
bil.descriptor_stats
# Out:
#                D         P         H   epsilon    pi_star        HBD  \
# count  24.000000  24.00000  24.00000  24.00000  24.000000  24.000000
# mean   16.341667   8.62500   9.31250  19.73125   0.639167   0.147917
# std     1.066452   3.59441   3.18498  11.43791   0.157956   0.204671
# min    15.200000   5.10000   4.00000   6.02000   0.410000   0.000000
# 25%    15.560000   5.37500   7.11000  11.30725   0.535500   0.000000
# 50%    15.770000   8.15000   8.75000  16.29600   0.585000   0.055000
# 75%    17.137500  10.56250  11.40000  25.08000   0.756250   0.205500
# max    18.700000  18.00000  17.40000  46.45000   1.000000   0.840000
#
#              HBA  logP_solv       r_sm     r_prod
# count  24.000000  24.000000  24.000000  24.000000
# mean    0.626667  -0.002083   7.300963   9.111257
# std     0.155391   0.639159   2.039909   3.363668
# min     0.400000  -1.380000   3.022400   2.641969
# 25%     0.487500  -0.398750   6.167702   6.544797
# 50%     0.623500   0.146500   7.353086   8.432362
# 75%     0.743500   0.586500   8.262033  12.091085
# max     0.930000   0.720000  12.834422  15.728001

# %%
bil.descriptor_df.quantile(q = 0.1)
# Out:
# D            15.356000
# P             5.192000
# H             6.370000
# epsilon       8.575200
# pi_star       0.474400
# HBD           0.000000
# HBA           0.453000
# logP_solv    -0.808500
# r_sm          4.841234
# r_prod        5.535218
# Name: 0.1, dtype: float64

# %%
bil.descriptor_df.min()
# Out:
# D            15.200000
# P             5.100000
# H             4.000000
# epsilon       6.020000
# pi_star       0.410000
# HBD           0.000000
# HBA           0.400000
# logP_solv    -1.380000
# r_sm          3.022400
# r_prod        2.641969
# dtype: float64

# %%
buffer_percent = 0.1
smooth_min_df = bil.descriptor_stats.loc['min'] - (bil.descriptor_df.quantile(q = buffer_percent) - bil.descriptor_stats.loc['min'])
smooth_min_df
# Out:
# D            15.044000
# P             5.008000
# H             1.630000
# epsilon       3.464800
# pi_star       0.345600
# HBD           0.000000
# HBA           0.347000
# logP_solv    -1.951500
# r_sm          1.203565
# r_prod       -0.251280
# dtype: float64

# %%
smooth_max_df = bil.descriptor_stats.loc['max'] + (bil.descriptor_stats.loc['max'] - bil.descriptor_df.quantile(q = 1 - buffer_percent))
smooth_max_df
# Out:
# D            19.450000
# P            22.960000
# H            21.530000
# epsilon      55.640000
# pi_star       1.126000
# HBD           1.272000
# HBA           1.036200
# logP_solv     0.763800
# r_sm         17.006317
# r_prod       17.879526
# dtype: float64

# %%
all_min_df = bil.descriptor_stats.loc['min']
all_min_df
# Out:
# D            15.200000
# P             5.100000
# H             4.000000
# epsilon       6.020000
# pi_star       0.410000
# HBD           0.000000
# HBA           0.400000
# logP_solv    -1.380000
# r_sm          3.022400
# r_prod        2.641969
# Name: min, dtype: float64

# %%
min_dict = all_min_df.to_dict()
min_dict.keys()
# Out:
# dict_keys(['D', 'P', 'H', 'epsilon', 'pi_star', 'HBD', 'HBA', 'logP_solv', 'r_sm', 'r_prod'])

# %%
bil.obs_series.index
# Out:
# Index(['Xf2346', 'Xf2353', 'Xf2345', 'Xf2344', 'Xf2352', 'Xf2350', 'Xf2351',
#        'Xf2356', 'xf2379', 'xf2380', 'xf2381', 'xf2382', 'xf2383', 'xf2384',
#        'xf2385', 'xf2386', 'xf2387', 'xf2388', 'xf2389', 'xf2391', 'xf2392',
#        'xf2393', 'xf2394', 'xf2396'],
#       dtype='object', name='rxn_id')

# %%
bil.descriptor_df.loc[bil.obs_series.index, :]
# Out:
#             D      P      H  epsilon  pi_star    HBD    HBA  logP_solv  \
# rxn_id
# Xf2346  16.80  11.50  10.20   37.780    0.880  0.000  0.760     -0.770
# Xf2353  15.50  10.40   7.00   20.700    0.600  0.100  0.500     -0.210
# Xf2345  18.40  16.40  10.20   46.450    1.000  0.000  0.760     -1.380
# Xf2344  17.40  13.70  11.30   36.700    0.880  0.000  0.690     -1.310
# Xf2352  15.30  18.00   6.10   37.500    0.750  0.190  0.400     -0.390
# Xf2350  16.00   6.80  17.40   20.450    0.520  0.840  0.900      0.360
# Xf2351  15.20   5.10  14.70   12.000    0.410  0.420  0.930      0.580
# Xf2356  15.80   5.30   7.20    6.020    0.550  0.000  0.450      0.710
# xf2379  15.56   9.38   7.04   17.764    0.590  0.080  0.490     -0.026
# xf2380  15.62   8.36   7.08   14.828    0.580  0.060  0.480      0.158
# xf2381  15.68   7.34   7.12   11.892    0.570  0.040  0.470      0.342
# xf2382  15.74   6.32   7.16    8.956    0.560  0.020  0.460      0.526
# xf2383  15.32   5.14  13.20   10.804    0.438  0.336  0.834      0.606
# xf2384  15.44   5.18  11.70    9.608    0.466  0.252  0.738      0.632
# xf2385  15.56   5.22  10.20    8.412    0.494  0.168  0.642      0.658
# xf2386  15.68   5.26   8.70    7.216    0.522  0.084  0.546      0.684
# xf2387  16.15   8.05   7.50   14.140    0.590  0.050  0.525      0.160
# xf2388  17.25   6.10   7.20   11.475    0.575  0.050  0.435     -0.240
# xf2389  16.65   5.40   4.00   11.560    0.660  0.050  0.605      0.720
# xf2391  15.65   8.25  11.70   20.310    0.540  0.430  0.670     -0.080
# xf2392  17.60  11.05   9.10   27.015    0.790  0.000  0.655     -0.425
# xf2393  18.70   9.10   8.80   24.350    0.775  0.000  0.565     -0.825
# xf2394  18.10   8.40   5.60   24.435    0.860  0.000  0.735      0.135
# xf2396  17.10  11.25  13.30   33.185    0.740  0.380  0.800     -0.665
#
#              r_sm     r_prod
# rxn_id
# Xf2346   4.843800  10.141006
# Xf2353   8.462175   7.942921
# Xf2345   7.907490  13.600368
# Xf2344   5.234539  12.269067
# Xf2352  12.834422  13.691603
# Xf2350   6.405029  15.728001
# Xf2351   7.371323  13.520725
# Xf2356   8.748394   6.225753
# xf2379   8.268494   7.348360
# xf2380   8.200024   6.857084
# xf2381   8.259879   6.492580
# xf2382   8.445330   6.276974
# xf2383   7.038409  12.031758
# xf2384   7.025696  10.551531
# xf2385   7.334848   9.084316
# xf2386   7.928304   7.637617
# xf2387   7.273026   6.562202
# xf2388   7.178886   5.239275
# xf2389  10.595206   2.641969
# xf2391   5.455722  10.690299
# xf2392   4.840134   8.892272
# xf2393   4.708121   7.972453
# xf2394   7.841454   4.657252
# xf2396   3.022400  12.614773

# %%
#check all descriptors names
bil.all_descpt_col_name
# Out:
# ['D',
#  'P',
#  'H',
#  'epsilon',
#  'pi_star',
#  'HBD',
#  'HBA',
#  'logP_solv',
#  'r_sm',
#  'r_prod']

# %%
#check selected descriptors name (by default, it should be same as all)
bil.descriptor_col_name
# Out:
# ['D',
#  'P',
#  'H',
#  'epsilon',
#  'pi_star',
#  'HBD',
#  'HBA',
#  'logP_solv',
#  'r_sm',
#  'r_prod']

# %%
#check descriptors data
bil.descriptor_df.head()
# Out:
#            D     P     H  epsilon  pi_star   HBD   HBA  logP_solv       r_sm  \
# rxn_id
# Xf2346  16.8  11.5  10.2    37.78     0.88  0.00  0.76      -0.77   4.843800
# Xf2353  15.5  10.4   7.0    20.70     0.60  0.10  0.50      -0.21   8.462175
# Xf2345  18.4  16.4  10.2    46.45     1.00  0.00  0.76      -1.38   7.907490
# Xf2344  17.4  13.7  11.3    36.70     0.88  0.00  0.69      -1.31   5.234539
# Xf2352  15.3  18.0   6.1    37.50     0.75  0.19  0.40      -0.39  12.834422
#
#            r_prod
# rxn_id
# Xf2346  10.141006
# Xf2353   7.942921
# Xf2345  13.600368
# Xf2344  12.269067
# Xf2352  13.691603

# %%
bil.descriptor_df.describe()
# Out:
#                D         P         H   epsilon    pi_star        HBD  \
# count  24.000000  24.00000  24.00000  24.00000  24.000000  24.000000
# mean   16.341667   8.62500   9.31250  19.73125   0.639167   0.147917
# std     1.066452   3.59441   3.18498  11.43791   0.157956   0.204671
# min    15.200000   5.10000   4.00000   6.02000   0.410000   0.000000
# 25%    15.560000   5.37500   7.11000  11.30725   0.535500   0.000000
# 50%    15.770000   8.15000   8.75000  16.29600   0.585000   0.055000
# 75%    17.137500  10.56250  11.40000  25.08000   0.756250   0.205500
# max    18.700000  18.00000  17.40000  46.45000   1.000000   0.840000
#
#              HBA  logP_solv       r_sm     r_prod
# count  24.000000  24.000000  24.000000  24.000000
# mean    0.626667  -0.002083   7.300963   9.111257
# std     0.155391   0.639159   2.039909   3.363668
# min     0.400000  -1.380000   3.022400   2.641969
# 25%     0.487500  -0.398750   6.167702   6.544797
# 50%     0.623500   0.146500   7.353086   8.432362
# 75%     0.743500   0.586500   8.262033  12.091085
# max     0.930000   0.720000  12.834422  15.728001
